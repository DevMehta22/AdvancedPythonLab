# %% [markdown]
# <a href="https://colab.research.google.com/github/DevMehta22/AdvancedPythonLab/blob/main/K_Means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans

# %%
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

# %%
df.fillna(df.mean(), inplace=True)
le = LabelEncoder()
df['target'] = le.fit_transform(df['target'])
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df.drop('target', axis=1))

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(df_scaled)
print("Cluster Centers:",kmeans.cluster_centers_)
# Out:
# Cluster Centers: [[ 0.57100359 -0.37176778  0.69111943  0.66315198]
#  [-0.81623084  1.31895771 -1.28683379 -1.2197118 ]
#  [-1.32765367 -0.373138   -1.13723572 -1.11486192]]

# %%
clusters = kmeans.predict(df_scaled)
plt.scatter(df_scaled[:, 0], df_scaled[:, 1], c=clusters, cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-Means Clustering')
plt.show()
